# %%
import importlib
import radar_tracking
import parse_bin_data

# %%
importlib.reload(radar_tracking)
importlib.reload(parse_bin_data)

fp = "no_people/no_people\pHistBytes_4.npy"

# data, output_file = parse_bin_data.parse_ADC(fp, output_file=None)

radar_tracking.process_radar_data(fp)
# Out:
# Estimated number of people: 9
# 9 people detected at 1701472973.0563579 seconds
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
